# %%
# 02_Visualization Notebook
# This notebook visualizes data, focusing on mean nitrogen concentration over the years and spatial distribution.

# Import necessary libraries
import sys
import os
import pandas as pd
sys.path.append('../src')  # Adjust this as necessary

from visualization import plot_mean_concentration_by_year, plot_spatial_distribution
from analysis import calculate_mean_concentration_by_year

# Load cleaned data
data_path = '../data/cleaned_water_quality.csv'
data = pd.read_csv(data_path)

# Calculate mean nitrogen concentration by year
mean_concentration = calculate_mean_concentration_by_year(data)

# Display mean nitrogen concentration by year
plot_mean_concentration_by_year(mean_concentration, None)

# Display spatial distribution of nitrogen concentration
plot_spatial_distribution(data, None)
# Out:
# 2024-08-10 11:02:28,143 - INFO - Mean concentration calculated by year
